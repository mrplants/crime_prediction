# %%
# %matplotlib inline

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.load(r'/home/muhammadayub/Desktop/CS230/training_data/minibatches_real/output_45_.npy')
a = a.astype(np.float32)

# %%
a.shape
# Out:
# (200, 64, 64)

# %%
for x in a:
    plt.imshow(x)
    plt.show()

# %%
a = np.load(r'/home/muhammadayub/Desktop/CS230/training_data/minibatches_real/output_56_.npy')
a = a.astype(np.float32)

# %%
for x in a:
    plt.imshow(x)
    plt.show()
